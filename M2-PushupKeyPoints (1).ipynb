# %% [markdown]
# ### Calc frames using angles

# %%
import cv2
import mediapipe as mp
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle

def bob(max, min):
    x = max - min
    y = x / 14
    list = []
    while max > min:
        list.append(max)
        max -= y
    return list

def double_reverse_array(min, max):
    x = max - min
    y = x / 15
    list = []
    while min <= max:
        list.append(min)
        min += y
    list.append(min)
    return list

def extract_key_pushup_frames(video_path, output_path):
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(video_path)
    elbow_angles = []
    frame_images = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle = calculate_angle(shoulder, elbow, wrist)
            elbow_angles.append((frame_count, angle))
            frame_images.append(frame)

        frame_count += 1

    cap.release()

    # Identify key frame indices
    selected_indices = []

    lowest_point = min(elbow_angles, key=lambda x: x[1])
    selected_indices.append(lowest_point[0])

    index = lowest_point[0]

    highest_point1 =  max(elbow_angles[:index], key=lambda x: x[1])
    selected_indices.append(highest_point1[0])

    highest_point2 = max(elbow_angles[index:], key=lambda x: x[1])
    selected_indices.append(highest_point2[0])

    target_angles = bob(highest_point1[1], lowest_point[1])
    target_angles2 = double_reverse_array(lowest_point[1], highest_point2[1])


    for target in target_angles:
        best_match = min(elbow_angles[:index], key=lambda x: abs(x[1] - target))
        selected_indices.append(best_match[0])

    for target in target_angles2:
        best_match = min(elbow_angles[index:], key=lambda x: abs(x[1] - target))
        selected_indices.append(best_match[0])

    selected_indices = sorted(set(selected_indices))

    # Save selected frames to output video
    height, width, _ = frame_images[0].shape
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), 1, (width, height))

    for idx in selected_indices:
        if idx < len(frame_images):
            out.write(frame_images[idx])

    out.release()
    print(f"Saved key push-up frames to {output_path}")

# Example usage
if __name__ == "__main__":
    INPUT_VIDEO = r"C:\Users\nikhi\PycharmProjects\pythonProject\fitDataa\fitDataa\Correct sequence\Copy of push up 1_flipped.mp4"
    OUTPUT_VIDEO = r"C:\Users\nikhi\PycharmProjects\pythonProject\output_keyframes.mp4"
    extract_key_pushup_frames(INPUT_VIDEO, OUTPUT_VIDEO)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 import mediapipe as mp
#       3 import pandas as pd
#       4 import os
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\__init__.py:17
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      20 del framework
#      21 del gpu
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\tasks\python\__init__.py:17
#       1 # Copyright 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Tasks API."""
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\tasks\python\audio\__init__.py:18
#      15 """MediaPipe Tasks Audio API."""
#      17 import mediapipe.tasks.python.audio.core
# ---> 18 import mediapipe.tasks.python.audio.audio_classifier
#      19 import mediapipe.tasks.python.audio.audio_embedder
#      21 AudioClassifier = audio_classifier.AudioClassifier
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\tasks\python\audio\audio_classifier.py:26
#      24 from mediapipe.tasks.cc.components.processors.proto import classifier_options_pb2
#      25 from mediapipe.tasks.python.audio.core import audio_task_running_mode as running_mode_module
# ---> 26 from mediapipe.tasks.python.audio.core import base_audio_task_api
#      27 from mediapipe.tasks.python.components.containers import audio_data as audio_data_module
#      28 from mediapipe.tasks.python.components.containers import classification_result as classification_result_module
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\tasks\python\audio\core\base_audio_task_api.py:25
#      23 from mediapipe.tasks.python.audio.core import audio_record
#      24 from mediapipe.tasks.python.audio.core import audio_task_running_mode as running_mode_module
# ---> 25 from mediapipe.tasks.python.core.optional_dependencies import doc_controls
#      27 _TaskRunner = task_runner_module.TaskRunner
#      28 _Packet = packet_module.Packet
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\tasks\python\core\optional_dependencies.py:20
#      16 # TensorFlow isn't a dependency of mediapipe pip package. It's only
#      17 # required in the API docgen pipeline so we'll ignore it if tensorflow is not
#      18 # installed.
#      19 try:
# ---> 20   from tensorflow.tools.docs import doc_controls
#      21 except ModuleNotFoundError:
#      22   # Replace the real doc_controls.do_not_generate_docs with an no-op
#      23   doc_controls = lambda: None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\combinations.py:33
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:26
#      24 from tensorflow.core.protobuf import tensorflow_server_pb2
#      25 from tensorflow.python.distribute import collective_util
# ---> 26 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      27 from tensorflow.python.distribute import cross_device_utils
#      28 from tensorflow.python.distribute import device_util
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\cross_device_ops.py:28
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\cross_device_utils.py:22
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\values.py:23
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\distribute\distribute_lib.py:205
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\experimental\__init__.py:99
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)     95 @@UNKNOWN_CARDINALITY
#      96 """
#      98 # pylint: disable=unused-import
# ---> 99 from tensorflow.python.data.experimental import service
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     101 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\experimental\service\__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)    416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:23
#      21 from tensorflow.core.protobuf import data_service_pb2
#      22 from tensorflow.python import tf2
# ---> 23 from tensorflow.python.data.experimental.ops import compression_ops
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils_exp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\util\structure.py:32
#      30 from tensorflow.python.ops import resource_variable_ops
#      31 from tensorflow.python.ops import tensor_array_ops
# ---> 32 from tensorflow.python.ops.ragged import ragged_tensor
#      33 from tensorflow.python.platform import tf_logging as logging
#      34 from tensorflow.python.types import internal
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\ragged\__init__.py:28
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ragged Tensors.
#      16
#      17 This package defines ops for manipulating ragged tensors (`tf.RaggedTensor`),
#    (...)     26 API docstring: tensorflow.ragged
#      27 """
# ---> 28 from tensorflow.python.ops.ragged import ragged_tensor
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\ragged\ragged_tensor.py:3149
#    3144 RaggedOrDense = typing.Union[Ragged, core_types.TensorLike]
#    3146 # RaggedTensor must import ragged_ops to ensure that all dispatched ragged ops
#    3147 # are registered. Ragged ops import RaggedTensor, so import at bottom of the
#    3148 # file to avoid a partially-initialized module error.
# -> 3149 from tensorflow.python.ops.ragged import ragged_ops  # pylint: disable=unused-import, g-bad-import-order, g-import-not-at-top
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\ragged\ragged_ops.py:41
#      39 from tensorflow.python.ops.ragged import ragged_gather_ops
#      40 from tensorflow.python.ops.ragged import ragged_getitem
# ---> 41 from tensorflow.python.ops.ragged import ragged_image_ops
#      42 from tensorflow.python.ops.ragged import ragged_map_ops
#      43 from tensorflow.python.ops.ragged import ragged_math_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\ragged\ragged_image_ops.py:24
#      22 from tensorflow.python.ops import array_ops
#      23 from tensorflow.python.ops import cond
# ---> 24 from tensorflow.python.ops import image_ops
#      25 from tensorflow.python.ops import map_fn
#      26 from tensorflow.python.ops import math_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\image_ops.py:159
#     156 # go/tf-wildcard-import
#     157 # pylint: disable=wildcard-import
#     158 from tensorflow.python.ops.gen_image_ops import *
# --> 159 from tensorflow.python.ops.image_ops_impl import *
#     160 # pylint: enable=wildcard-import
#     161
#     162 # TODO(drpng): remove these once internal use has discontinued.
#     163 # pylint: disable=unused-import
#     164 from tensorflow.python.ops.image_ops_impl import _Check3DImage
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\image_ops_impl.py:40
#      38 from tensorflow.python.ops import gen_image_ops
#      39 from tensorflow.python.ops import math_ops
# ---> 40 from tensorflow.python.ops import nn_impl
#      41 from tensorflow.python.ops import nn_ops
#      42 from tensorflow.python.ops import random_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\nn_impl.py:26
#      24 from tensorflow.python.ops import candidate_sampling_ops
#      25 from tensorflow.python.ops import cond as tf_cond
# ---> 26 from tensorflow.python.ops import ctc_ops  # pylint: disable=unused-import
#      27 from tensorflow.python.ops import custom_gradient
#      28 from tensorflow.python.ops import embedding_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\ctc_ops.py:32
#      30 from tensorflow.python.ops import array_ops
#      31 from tensorflow.python.ops import array_ops_stack
# ---> 32 from tensorflow.python.ops import custom_gradient
#      33 from tensorflow.python.ops import functional_ops
#      34 from tensorflow.python.ops import gen_array_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\custom_gradient.py:17
#       1 # Copyright 2017 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Decorator to overrides the gradient for a function."""
# ---> 17 from tensorflow.python.eager import backprop
#      18 from tensorflow.python.eager import context
#      19 from tensorflow.python.eager import record
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\backprop.py:45
#      43 from tensorflow.python.ops import gen_array_ops
#      44 from tensorflow.python.ops import gen_math_ops
# ---> 45 from tensorflow.python.ops import gradients_impl  # pylint: disable=unused-import
#      46 from tensorflow.python.ops import resource_variable_ops
#      47 from tensorflow.python.ops.parallel_for import control_flow_ops as pfor_ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\gradients_impl.py:28
#      26 from tensorflow.python.ops import image_grad  # pylint: disable=unused-import
#      27 from tensorflow.python.ops import io_ops  # pylint: disable=unused-import
# ---> 28 from tensorflow.python.ops import linalg_grad  # pylint: disable=unused-import
#      29 from tensorflow.python.ops import linalg_ops  # pylint: disable=unused-import
#      30 from tensorflow.python.ops import logging_ops  # pylint: disable=unused-import
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\ops\linalg_grad.py:47
#      43 from tensorflow.python.ops import math_ops
#      44 from tensorflow.python.ops.linalg import linalg_impl as _linalg
# ---> 47 @ops.RegisterGradient("MatrixInverse")
#      48 def _MatrixInverseGrad(op: ops.Operation, grad):
#      49   """Gradient for MatrixInverse."""
#      50   ainv = op.outputs[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\framework\ops.py:1722, in RegisterGradient.__call__(self, f)
#    1720 def __call__(self, f: _T) -> _T:
#    1721   """Registers the function `f` as gradient function for `op_type`."""
# -> 1722   gradient_registry.register(f, self._op_type)
#    1723   return f
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\framework\registry.py:65, in Registry.register(self, candidate, name)
#      62 logging.vlog(1, "Registering %s (%s) in %s.", name, candidate, self._name)
#      63 # stack trace is [this_function, Register(), user_function,...]
#      64 # so the user function is #2.
# ---> 65 stack = traceback.extract_stack(limit=3)
#      66 stack_index = min(2, len(stack) - 1)
#      67 if stack_index >= 0:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\traceback.py:228, in extract_stack(f, limit)
#     226 if f is None:
#     227     f = sys._getframe().f_back
# --> 228 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     229 stack.reverse()
#     230 return stack
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\traceback.py:390, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     387     for f, lineno in frame_gen:
#     388         yield f, (lineno, None, None, None)
# --> 390 return klass._extract_from_extended_frame_gen(
#     391     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     392     capture_locals=capture_locals)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\traceback.py:433, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     431 if lookup_lines:
#     432     for f in result:
# --> 433         f.line
#     434 return result
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\traceback.py:318, in FrameSummary.line(self)
#     316     if self.lineno is None:
#     317         return None
# --> 318     self._line = linecache.getline(self.filename, self.lineno)
#     319 return self._line.strip()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except (OSError, UnicodeDecodeError, SyntaxError):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\tokenize.py:396, in open(filename)
#     392 def open(filename):
#     393     """Open a file in read only mode using the encoding detected by
#     394     detect_encoding().
#     395     """
# --> 396     buffer = _builtin_open(filename, 'rb')
#     397     try:
#     398         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:

# %%
import cv2
import mediapipe as mp
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle
"""
def bob(max, min):
    x = max - min
    y = x / 14
    list = []
    while max > min:
        list.append(max)
        max -= y
    return list

def double_reverse_array(min, max):
    x = max - min
    y = x / 15
    list = []
    while min <= max:
        list.append(min)
        min += y
    list.append(min)
    return list
"""
def extract_key_pushup_frames(video_path, output_path):
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(video_path)
    elbow_angles = []
    frame_images = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle = calculate_angle(shoulder, elbow, wrist)
            elbow_angles.append((frame_count, angle))
            frame_images.append(frame)

        frame_count += 1

    cap.release()

    # Identify key frame indices
    selected_indices = []

    lowest_point = min(elbow_angles, key=lambda x: x[1])
    selected_indices.append(lowest_point[0])

    index = lowest_point[0]

    highest_point1 =  max(elbow_angles[:index], key=lambda x: x[1])
    selected_indices.append(highest_point1[0])

    highest_point2 = max(elbow_angles[index:], key=lambda x: x[1])
    selected_indices.append(highest_point2[0])

    """
    target_angles = bob(highest_point1[1], lowest_point[1])
    target_angles2 = double_reverse_array(lowest_point[1], highest_point2[1])

    for target in target_angles:
        best_match = min(elbow_angles[:index], key=lambda x: abs(x[1] - target))
        selected_indices.append(best_match[0])

    for target in target_angles2:
        best_match = min(elbow_angles[index:], key=lambda x: abs(x[1] - target))
        selected_indices.append(best_match[0])
    """

    selected_indices = sorted(set(selected_indices))
    print(f"Selected frame indices: {selected_indices}")
    """
    # Save selected frames to output video
    height, width, _ = frame_images[0].shape
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), 1, (width, height))

    for idx in selected_indices:
        if idx < len(frame_images):
            out.write(frame_images[idx])

    out.release()
    print(f"Saved key push-up frames to {output_path}")
    """

# Example usage
if __name__ == "__main__":
    INPUT_VIDEO = r"C:\Users\nikhi\PycharmProjects\pythonProject\fitDataa\fitDataa\Correct sequence\Copy of push up 1_flipped.mp4"
    OUTPUT_VIDEO = r"C:\Users\nikhi\PycharmProjects\pythonProject\output_keyframes.mp4"
    extract_key_pushup_frames(INPUT_VIDEO, OUTPUT_VIDEO)

# %%
# %pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.10.21)
# Requirement already satisfied: absl-py in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (3.10.3)
# Requirement already satisfied: numpy<2 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jax->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\12484\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# INFO: pip is looking at multiple versions of opencv-contrib-python to determine which version is compatible with other requirements. This could take a while.
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
# Installing collected packages: opencv-contrib-python
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\12484\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\12484\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\12484\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\12484\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.

# %%
import cv2
import mediapipe as mp
import pandas as pd
import os
import numpy as np
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle

def extract_key_pushup_frames(video_path, output_path):
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(video_path)
    elbow_angles = []
    frame_images = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle = calculate_angle(shoulder, elbow, wrist)
            elbow_angles.append((frame_count, angle))
            frame_images.append(frame)

        frame_count += 1

    cap.release()

    # Identify key frame indices
    selected_indices = []

    lowest_point = min(elbow_angles, key=lambda x: x[1])
    selected_indices.append(lowest_point[0])

    index = lowest_point[0]

    highest_point1 =  max(elbow_angles[:index], key=lambda x: x[1])
    selected_indices.append(highest_point1[0])

    highest_point2 = max(elbow_angles[index:], key=lambda x: x[1])
    selected_indices.append(highest_point2[0])

    
    selected_indices = sorted(set(selected_indices))
    print(f"Selected frame indices: {selected_indices}")
    
    # Save selected frames to output video
    height, width, _ = frame_images[0].shape
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), 1, (width, height))

    for idx in selected_indices:
        if idx < len(frame_images):
            out.write(frame_images[idx])

    out.release()
    print(f"Saved key push-up frames to {output_path}")

    

# Process Video in RepVids Directory
print("Processing videos from RepVids:")
for video_file in os.listdir(videos_path):
    if video_file.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
        video_path = os.path.join(videos_path, video_file)
        output_filename = f"key_frames_{video_file}"    # defines output format
        output_path = os.path.join(save_dir, output_filename)
        extract_key_pushup_frames(video_path, output_path)

print(f"\nAll processed videos saved to: {save_dir}")
# Out:
# Processing videos from RepVids:
# Selected frame indices: [22, 78, 90]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 100_flipped_rep_001.mp4
# Selected frame indices: [24, 80, 91]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 100_rep_001.mp4
# Selected frame indices: [0, 31, 44]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 101_flipped_rep_001.mp4
# Selected frame indices: [0, 34, 45]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 101_rep_001.mp4
# Selected frame indices: [0, 37, 52]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 102_flipped_rep_001.mp4
# Selected frame indices: [0, 37, 54]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 102_rep_001.mp4
# Selected frame indices: [0, 32, 45]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 113_flipped_rep_001.mp4
# Selected frame indices: [0, 33, 47]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 113_rep_001.mp4
# Selected frame indices: [0, 39, 52]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 114_flipped_rep_001.mp4
# Selected frame indices: [4, 38, 54]
# Saved key push-up frames to C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\key_frames_correct_Copy of push up 114_rep_001.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 88
#      86         output_filename = f"key_frames_{video_file}"
#      87         output_path = os.path.join(save_dir, output_filename)
# ---> 88         extract_key_pushup_frames(video_path, output_path)
#      90 print(f"\nAll processed videos saved to: {save_dir}")
#
# Cell In[1], line 35, in extract_key_pushup_frames(video_path, output_path)
#      32     break
#      34 image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ---> 35 results = pose.process(image_rgb)
#      37 if results.pose_landmarks:
#      38     lm = results.pose_landmarks.landmark
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)    182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import os
import mediapipe as mp
import pandas as pd
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle

def extract_key_pushup_frames(video_path, output_path):
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(video_path)
    elbow_angles = []
    frame_images = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            angle = calculate_angle(shoulder, elbow, wrist)
            elbow_angles.append((frame_count, angle))
            frame_images.append(frame)

        frame_count += 1

    cap.release()

    # Identify key frame indices
    selected_indices = []

    lowest_point = min(elbow_angles, key=lambda x: x[1])
    selected_indices.append(lowest_point[0])

    index = lowest_point[0]

    highest_point1 =  max(elbow_angles[:index], key=lambda x: x[1])
    selected_indices.append(highest_point1[0])

    highest_point2 = max(elbow_angles[index:], key=lambda x: x[1])
    selected_indices.append(highest_point2[0])

    
    selected_indices = sorted(set(selected_indices))
    print(f"Selected frame indices: {selected_indices}")
    
    # Save selected frames to output video
    height, width, _ = frame_images[0].shape
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), 1, (width, height))

    for idx in selected_indices:
        if idx < len(frame_images):
            out.write(frame_images[idx])

    out.release()
    print(f"Saved key push-up frames to {output_path}")

def downsample_to_30_frames(input_path, output_path):
    cap = cv2.VideoCapture(input_path)
    
    # Get video properties
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    
    print(f"Input: {total_frames} frames")
    
    # Target exactly 30 frames
    target_frames = 30
    
    if total_frames <= target_frames:
        selected_indices = list(range(total_frames))
    else:
        selected_indices = np.linspace(0, total_frames - 1, target_frames, dtype=int)
    
    print(f"Selected indices: {selected_indices}")
    
    # Create output video writer
    out = cv2.VideoWriter(output_path, fourcc, 10.0, (width, height))
    
    # Extract selected frames
    for i, frame_idx in enumerate(selected_indices):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        
        if ret:
            out.write(frame)
        else:
            print(f"❌ Failed to read frame {frame_idx}")
    
    cap.release()
    out.release()
    print(f"✅ Output: {len(selected_indices)} frames saved")

# Process all videos in RepKeys directory to exactly 30 frames
def process_repkeys_to_30_frames():
    # Input and output directories
    input_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepVids")
    output_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepKeys")
    
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"🎬 Processing videos from: {input_dir}")
    print(f"💾 Saving 30-frame videos to: {output_dir}")
    
    # Process each video file
    for video_file in os.listdir(input_dir):
        if video_file.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
            input_path = os.path.join(input_dir, video_file)
            output_filename = f"30frames_{video_file}"
            output_path = os.path.join(output_dir, output_filename)
            
            print(f"\n🔄 Processing: {video_file}")
            downsample_to_30_frames(input_path, output_path)
    
    print(f"\n🎉 All videos processed and saved to: {output_dir}")

# Run the processing
process_repkeys_to_30_frames()

# %%
import cv2
import numpy as np
import os
import mediapipe as mp
import pandas as pd
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle

def extract_key_frames_and_downsample_to_30(input_path, output_path):
    """
    Combined function: Extract key pushup frames THEN downsample to exactly 30 frames
    """
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(input_path)
    elbow_angles = []
    frame_images = []
    frame_count = 0

    print(f"🔍 Analyzing frames for key points...")
    
    # STEP 1: Extract frames with pose landmarks and calculate angles
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            
            # Try both sides - use whichever is more visible
            try:
                # Try LEFT side first
                left_shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                left_elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                left_wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                
                left_visibility = (lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].visibility + 
                                 lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].visibility + 
                                 lm[mp_pose.PoseLandmark.LEFT_WRIST.value].visibility) / 3
                
                # Try RIGHT side
                right_shoulder = [lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                right_elbow = [lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                right_wrist = [lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                
                right_visibility = (lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].visibility + 
                                  lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].visibility + 
                                  lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].visibility) / 3
                
                # Use the side with better visibility
                if left_visibility >= right_visibility and left_visibility > 0.5:
                    shoulder, elbow, wrist = left_shoulder, left_elbow, left_wrist
                elif right_visibility > 0.5:
                    shoulder, elbow, wrist = right_shoulder, right_elbow, right_wrist
                else:
                    frame_count += 1
                    continue
                
                angle = calculate_angle(shoulder, elbow, wrist)
                elbow_angles.append((frame_count, angle))
                frame_images.append(frame)
                
            except:
                pass

        frame_count += 1

    cap.release()
    
    if len(elbow_angles) < 3:
        print(f"❌ Not enough frames with pose landmarks ({len(elbow_angles)}). Skipping...")
        return False

    # STEP 2: Identify key frame indices based on elbow angles
    print(f"📊 Found {len(elbow_angles)} frames with pose data")
    
    selected_indices = []

    # Find lowest point (most bent elbow)
    lowest_point = min(elbow_angles, key=lambda x: x[1])
    selected_indices.append(lowest_point[0])
    index = lowest_point[0]

    # Find highest points before and after lowest point
    if index > 0:
        highest_point1 = max(elbow_angles[:index], key=lambda x: x[1])
        selected_indices.append(highest_point1[0])

    if index < len(elbow_angles) - 1:
        highest_point2 = max(elbow_angles[index:], key=lambda x: x[1])
        selected_indices.append(highest_point2[0])

    # Remove duplicates and sort
    selected_indices = sorted(set(selected_indices))
    print(f"🎯 Key frame indices: {selected_indices}")
    
    # STEP 3: Extract key frames
    key_frames = []
    for idx in selected_indices:
        if idx < len(frame_images):
            key_frames.append(frame_images[idx])
    
    if len(key_frames) == 0:
        print(f"❌ No key frames extracted. Skipping...")
        return False
    
    print(f"🔑 Extracted {len(key_frames)} key frames")
    
    # STEP 4: Downsample to exactly 30 frames
    target_frames = 30
    
    if len(key_frames) <= target_frames:
        # If we have 30 or fewer key frames, use all of them
        final_frames = key_frames
        print(f"📦 Using all {len(key_frames)} key frames (≤30)")
    else:
        # If we have more than 30, downsample evenly
        selected_frame_indices = np.linspace(0, len(key_frames) - 1, target_frames, dtype=int)
        final_frames = [key_frames[i] for i in selected_frame_indices]
        print(f"⬇️ Downsampled from {len(key_frames)} to {len(final_frames)} frames")
    
    # STEP 5: Save output video
    if len(final_frames) > 0:
        height, width, _ = final_frames[0].shape
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, 10.0, (width, height))
        
        for frame in final_frames:
            out.write(frame)
        
        out.release()
        print(f"✅ Saved {len(final_frames)} frames to: {output_path}")
        return True
    else:
        print(f"❌ No frames to save")
        return False

# Process all videos in RepVids directory
def process_repvids_to_repkeys():
    """
    Process all videos in RepVids: Extract key frames → Downsample to 30 frames → Save to RepKeys
    """
    # Input and output directories
    input_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepVids")
    output_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepKeys")
    
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"🎬 Processing videos from: {input_dir}")
    print(f"💾 Saving processed videos to: {output_dir}")
    print(f"🎯 Target: Key frames → 30 frames max\n")
    
    # Get all video files
    video_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.mp4', '.avi', '.mov', '.mkv'))]
    
    if not video_files:
        print("❌ No video files found in RepVids directory!")
        return
    
    successful = 0
    failed = 0
    
    # Process each video file
    for i, video_file in enumerate(video_files, 1):
        input_path = os.path.join(input_dir, video_file)
        output_filename = f"keyframes_30_{video_file}"
        output_path = os.path.join(output_dir, output_filename)
        
        print(f"[{i}/{len(video_files)}] 🔄 Processing: {video_file}")
        
        try:
            success = extract_key_frames_and_downsample_to_30(input_path, output_path)
            if success:
                successful += 1
                print(f"✅ Success!\n")
            else:
                failed += 1
                print(f"❌ Failed!\n")
        except Exception as e:
            failed += 1
            print(f"❌ Error: {e}\n")
    
    print("="*60)
    print(f"🎉 PROCESSING COMPLETE!")
    print(f"✅ Successful: {successful}")
    print(f"❌ Failed: {failed}")
    print(f"📁 Output directory: {output_dir}")
    print("="*60)

    # Return the counts so they can be accessed outside the function
    return successful, failed

# Run the processing
if __name__ == "__main__":
    successful, failed = process_repvids_to_repkeys()
# Out:
# 🎬 Processing videos from: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepVids
# 💾 Saving processed videos to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys
# 🎯 Target: Key frames → 30 frames max
#
# [1/187] 🔄 Processing: correct_Copy of push up 100_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 91 frames with pose data
# 🎯 Key frame indices: [22, 78, 90]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 100_flipped_rep_001.mp4
# ✅ Success!
#
# [2/187] 🔄 Processing: correct_Copy of push up 100_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 92 frames with pose data
# 🎯 Key frame indices: [0, 79, 91]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 100_rep_001.mp4
# ✅ Success!
#
# [3/187] 🔄 Processing: correct_Copy of push up 101_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 45 frames with pose data
# 🎯 Key frame indices: [0, 31, 44]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 101_flipped_rep_001.mp4
# ✅ Success!
#
# [4/187] 🔄 Processing: correct_Copy of push up 101_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 46 frames with pose data
# 🎯 Key frame indices: [0, 34, 45]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 101_rep_001.mp4
# ✅ Success!
#
# [5/187] 🔄 Processing: correct_Copy of push up 102_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 53 frames with pose data
# 🎯 Key frame indices: [0, 37, 52]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 102_flipped_rep_001.mp4
# ✅ Success!
#
# [6/187] 🔄 Processing: correct_Copy of push up 102_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 55 frames with pose data
# 🎯 Key frame indices: [0, 43, 54]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 102_rep_001.mp4
# ✅ Success!
#
# [7/187] 🔄 Processing: correct_Copy of push up 113_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 46 frames with pose data
# 🎯 Key frame indices: [0, 32, 45]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 113_flipped_rep_001.mp4
# ✅ Success!
#
# [8/187] 🔄 Processing: correct_Copy of push up 113_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 48 frames with pose data
# 🎯 Key frame indices: [0, 37, 47]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 113_rep_001.mp4
# ✅ Success!
#
# [9/187] 🔄 Processing: correct_Copy of push up 114_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 53 frames with pose data
# 🎯 Key frame indices: [0, 39, 52]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 114_flipped_rep_001.mp4
# ✅ Success!
#
# [10/187] 🔄 Processing: correct_Copy of push up 114_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 55 frames with pose data
# 🎯 Key frame indices: [4, 38, 54]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 114_rep_001.mp4
# ✅ Success!
#
# [11/187] 🔄 Processing: correct_Copy of push up 115_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 97 frames with pose data
# 🎯 Key frame indices: [16, 84, 96]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 115_flipped_rep_001.mp4
# ✅ Success!
#
# [12/187] 🔄 Processing: correct_Copy of push up 115_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 99 frames with pose data
# 🎯 Key frame indices: [31, 86, 98]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 115_rep_001.mp4
# ✅ Success!
#
# [13/187] 🔄 Processing: correct_Copy of push up 116_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 27 frames with pose data
# 🎯 Key frame indices: [0, 18, 26]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 116_flipped_rep_001.mp4
# ✅ Success!
#
# [14/187] 🔄 Processing: correct_Copy of push up 116_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 27 frames with pose data
# 🎯 Key frame indices: [0, 20, 26]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 116_rep_001.mp4
# ✅ Success!
#
# [15/187] 🔄 Processing: correct_Copy of push up 127_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 70 frames with pose data
# 🎯 Key frame indices: [19, 55, 69]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 127_flipped_rep_001.mp4
# ✅ Success!
#
# [16/187] 🔄 Processing: correct_Copy of push up 127_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 70 frames with pose data
# 🎯 Key frame indices: [0, 52, 69]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 127_rep_001.mp4
# ✅ Success!
#
# [17/187] 🔄 Processing: correct_Copy of push up 129_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 62 frames with pose data
# 🎯 Key frame indices: [5, 43, 61]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 129_flipped_rep_001.mp4
# ✅ Success!
#
# [18/187] 🔄 Processing: correct_Copy of push up 129_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 62 frames with pose data
# 🎯 Key frame indices: [0, 50, 61]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 129_rep_001.mp4
# ✅ Success!
#
# [19/187] 🔄 Processing: correct_Copy of push up 131_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 36 frames with pose data
# 🎯 Key frame indices: [1, 24, 35]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 131_flipped_rep_001.mp4
# ✅ Success!
#
# [20/187] 🔄 Processing: correct_Copy of push up 131_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 36 frames with pose data
# 🎯 Key frame indices: [1, 23, 35]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 131_rep_001.mp4
# ✅ Success!
#
# [21/187] 🔄 Processing: correct_Copy of push up 132_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 38 frames with pose data
# 🎯 Key frame indices: [3, 26, 37]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 132_flipped_rep_001.mp4
# ✅ Success!
#
# [22/187] 🔄 Processing: correct_Copy of push up 132_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 38 frames with pose data
# 🎯 Key frame indices: [3, 26, 37]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 132_rep_001.mp4
# ✅ Success!
#
# [23/187] 🔄 Processing: correct_Copy of push up 133_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 35 frames with pose data
# 🎯 Key frame indices: [1, 24, 34]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 133_flipped_rep_001.mp4
# ✅ Success!
#
# [24/187] 🔄 Processing: correct_Copy of push up 133_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 35 frames with pose data
# 🎯 Key frame indices: [0, 22, 34]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 133_rep_001.mp4
# ✅ Success!
#
# [25/187] 🔄 Processing: correct_Copy of push up 134_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 34 frames with pose data
# 🎯 Key frame indices: [1, 22, 33]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 134_flipped_rep_001.mp4
# ✅ Success!
#
# [26/187] 🔄 Processing: correct_Copy of push up 134_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 35 frames with pose data
# 🎯 Key frame indices: [1, 20, 34]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 134_rep_001.mp4
# ✅ Success!
#
# [27/187] 🔄 Processing: correct_Copy of push up 135_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 31 frames with pose data
# 🎯 Key frame indices: [0, 20, 30]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 135_flipped_rep_001.mp4
# ✅ Success!
#
# [28/187] 🔄 Processing: correct_Copy of push up 135_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 31 frames with pose data
# 🎯 Key frame indices: [1, 20, 30]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 135_rep_001.mp4
# ✅ Success!
#
# [29/187] 🔄 Processing: correct_Copy of push up 136_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 32 frames with pose data
# 🎯 Key frame indices: [1, 20, 31]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 136_flipped_rep_001.mp4
# ✅ Success!
#
# [30/187] 🔄 Processing: correct_Copy of push up 136_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 33 frames with pose data
# 🎯 Key frame indices: [1, 21, 32]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 136_rep_001.mp4
# ✅ Success!
#
# [31/187] 🔄 Processing: correct_Copy of push up 137_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 31 frames with pose data
# 🎯 Key frame indices: [0, 18, 30]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 137_flipped_rep_001.mp4
# ✅ Success!
#
# [32/187] 🔄 Processing: correct_Copy of push up 137_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 31 frames with pose data
# 🎯 Key frame indices: [0, 18, 30]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 137_rep_001.mp4
# ✅ Success!
#
# [33/187] 🔄 Processing: correct_Copy of push up 138_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 33 frames with pose data
# 🎯 Key frame indices: [1, 20, 32]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 138_flipped_rep_001.mp4
# ✅ Success!
#
# [34/187] 🔄 Processing: correct_Copy of push up 138_rep_001.mp4
# 🔍 Analyzing frames for key points...
# 📊 Found 33 frames with pose data
# 🎯 Key frame indices: [0, 19, 32]
# 🔑 Extracted 3 key frames
# 📦 Using all 3 key frames (≤30)
# ✅ Saved 3 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 138_rep_001.mp4
# ✅ Success!
#
# [35/187] 🔄 Processing: correct_Copy of push up 140_flipped_rep_001.mp4
# 🔍 Analyzing frames for key points...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 202
#     200 # Run the processing
#     201 if __name__ == "__main__":
# --> 202     process_repvids_to_repkeys()
#
# Cell In[2], line 182, in process_repvids_to_repkeys()
#     179 print(f"[{i}/{len(video_files)}] 🔄 Processing: {video_file}")
#     181 try:
# --> 182     success = extract_key_frames_and_downsample_to_30(input_path, output_path)
#     183     if success:
#     184         successful += 1
#
# Cell In[2], line 35, in extract_key_frames_and_downsample_to_30(input_path, output_path)
#      32     break
#      34 image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
# ---> 35 results = pose.process(image_rgb)
#      37 if results.pose_landmarks:
#      38     lm = results.pose_landmarks.landmark
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)    182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### *Downsampling to 30

# %%
import cv2
import numpy as np
import os
import mediapipe as mp
import pandas as pd
from tqdm import tqdm

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    return angle if angle <= 180 else 360 - angle

def extract_key_frames_and_downsample_to_30(input_path, output_path):
    """
    Extract frames between key points and downsample to 30 frames with guaranteed minimum elbow angle
    """
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.7)

    cap = cv2.VideoCapture(input_path)
    elbow_angles = []
    frame_count = 0

    print(f"Analyzing frames for key points...")
    
    # STEP 1: First pass - extract frames and calculate angles
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:
            lm = results.pose_landmarks.landmark
            
            # Try both sides - use whichever is more visible
            try:
                # Try LEFT side first
                left_shoulder = [lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                left_elbow = [lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                left_wrist = [lm[mp_pose.PoseLandmark.LEFT_WRIST.value].x, lm[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                
                left_visibility = (lm[mp_pose.PoseLandmark.LEFT_SHOULDER.value].visibility + 
                                 lm[mp_pose.PoseLandmark.LEFT_ELBOW.value].visibility + 
                                 lm[mp_pose.PoseLandmark.LEFT_WRIST.value].visibility) / 3
                
                # Try RIGHT side
                right_shoulder = [lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                right_elbow = [lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                right_wrist = [lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                
                right_visibility = (lm[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].visibility + 
                                  lm[mp_pose.PoseLandmark.RIGHT_ELBOW.value].visibility + 
                                  lm[mp_pose.PoseLandmark.RIGHT_WRIST.value].visibility) / 3
                
                # Use the side with better visibility
                if left_visibility >= right_visibility and left_visibility > 0.5:
                    shoulder, elbow, wrist = left_shoulder, left_elbow, left_wrist
                elif right_visibility > 0.5:
                    shoulder, elbow, wrist = right_shoulder, right_elbow, right_wrist
                else:
                    frame_count += 1
                    continue
                
                angle = calculate_angle(shoulder, elbow, wrist)
                elbow_angles.append((frame_count, angle))
                
            except:
                pass

        frame_count += 1

    cap.release()
    
    if len(elbow_angles) < 3:
        print(f"Not enough frames with pose landmarks ({len(elbow_angles)}). Skipping...")
        return False

    # STEP 2: Identify key frame indices based on elbow angles
    print(f"Found {len(elbow_angles)} frames with pose data")
    
    # Find lowest point (most bent elbow) - MUST be included
    lowest_point = min(elbow_angles, key=lambda x: x[1])
    lowest_frame_index = lowest_point[0]
    
    print(f"Minimum elbow angle: {lowest_point[1]:.1f}° at frame {lowest_frame_index}")

    # Find highest points before and after lowest point
    key_indices = []
    
    if lowest_frame_index > 0:
        # Find frames with pose data before the lowest point
        before_frames = [(idx, angle) for idx, angle in elbow_angles if idx < lowest_frame_index]
        if before_frames:
            highest_before = max(before_frames, key=lambda x: x[1])
            start_frame = highest_before[0]
            print(f"Start frame: {start_frame} (angle: {highest_before[1]:.1f}°)")
        else:
            start_frame = 0
    else:
        start_frame = 0

    if lowest_frame_index < frame_count - 1:
        # Find frames with pose data after the lowest point
        after_frames = [(idx, angle) for idx, angle in elbow_angles if idx > lowest_frame_index]
        if after_frames:
            highest_after = max(after_frames, key=lambda x: x[1])
            end_frame = highest_after[0]
            print(f"End frame: {end_frame} (angle: {highest_after[1]:.1f}°)")
        else:
            end_frame = frame_count - 1
    else:
        end_frame = frame_count - 1

    print(f"Extracting frames from {start_frame} to {end_frame} (total: {end_frame - start_frame + 1} frames)")
    
    # STEP 3: Extract all frames between key points
    cap = cv2.VideoCapture(input_path)
    all_frames_in_range = []
    frame_indices_in_range = []
    
    current_frame = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        if start_frame <= current_frame <= end_frame:
            all_frames_in_range.append(frame)
            frame_indices_in_range.append(current_frame)
            
        current_frame += 1
        
        # Stop if we've passed the end frame
        if current_frame > end_frame:
            break

    cap.release()
    
    if len(all_frames_in_range) == 0:
        print(f"No frames extracted in range. Skipping...")
        return False
    
    print(f"Extracted {len(all_frames_in_range)} frames between key points")
    
    # STEP 4: Downsample to exactly 30 frames while ensuring minimum angle frame is included
    target_frames = 30
    
    if len(all_frames_in_range) <= target_frames:
        # If we have 30 or fewer frames, use all of them
        final_frames = all_frames_in_range
        final_indices = frame_indices_in_range
        print(f"Using all {len(all_frames_in_range)} frames (≤30)")
    else:
        # Downsample but GUARANTEE the minimum elbow angle frame is included
        
        # Find the position of the minimum elbow angle frame in our extracted range
        min_frame_position_in_range = lowest_frame_index - start_frame
        
        # Create evenly spaced indices
        selected_positions = np.linspace(0, len(all_frames_in_range) - 1, target_frames, dtype=int)
        
        # Ensure the minimum elbow angle frame is included
        if min_frame_position_in_range not in selected_positions:
            # Replace the closest selected position with the minimum angle frame position
            closest_idx = np.argmin(np.abs(selected_positions - min_frame_position_in_range))
            selected_positions[closest_idx] = min_frame_position_in_range
            selected_positions = np.sort(selected_positions)
        
        final_frames = [all_frames_in_range[i] for i in selected_positions]
        final_indices = [frame_indices_in_range[i] for i in selected_positions]
        
        print(f"⬇Downsampled from {len(all_frames_in_range)} to {len(final_frames)} frames")
        print(f"Minimum elbow angle frame {lowest_frame_index} is guaranteed to be included")
    
    # STEP 5: Save output video
    if len(final_frames) > 0:
        height, width, _ = final_frames[0].shape
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, 10.0, (width, height))
        
        for frame in final_frames:
            out.write(frame)
        
        out.release()
        print(f"Saved {len(final_frames)} frames to: {output_path}")
        return True
    else:
        print(f"No frames to save")
        return False

# Process all videos in RepVids directory
def process_repvids_to_repkeys():
    """
    Process all videos in RepVids: Extract frames between key points → Downsample to 30 frames → Save to RepKeys
    """
    # Input and output directories
    input_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepVids")
    output_dir = os.path.join(os.path.expanduser("~"), "Desktop", "Deep Dive AI Summer 2025", "RepKeys")
    
    os.makedirs(output_dir, exist_ok=True)
    
    print(f"Processing videos from: {input_dir}")
    print(f"Saving processed videos to: {output_dir}")
    print(f"Target: Extract frames between key points → 30 frames max with guaranteed minimum elbow angle\n")
    
    # Get all video files
    video_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.mp4', '.avi', '.mov', '.mkv'))]
    
    if not video_files:
        print("No video files found in RepVids directory!")
        return 0, 0
    
    successful = 0
    failed = 0
    
    # Process each video file
    for i, video_file in enumerate(video_files, 1):
        input_path = os.path.join(input_dir, video_file)
        output_filename = f"keyframes_30_{video_file}"
        output_path = os.path.join(output_dir, output_filename)
        
        print(f"[{i}/{len(video_files)}] Processing: {video_file}")
        
        try:
            success = extract_key_frames_and_downsample_to_30(input_path, output_path)
            if success:
                successful += 1
                print(f"Success!\n")
            else:
                failed += 1
                print(f"Failed!\n")
        except Exception as e:
            failed += 1
            print(f"Error: {e}\n")
    
    print("="*60)
    print(f"PROCESSING COMPLETE!")
    print(f"Successful: {successful}")
    print(f"Failed: {failed}")
    print(f"Output directory: {output_dir}")
    print("="*60)

    # Return the counts so they can be accessed outside the function
    return successful, failed

# Run the processing
if __name__ == "__main__":
    successful, failed = process_repvids_to_repkeys()
# Out:
# Processing videos from: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepVids
# Saving processed videos to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys
# Target: Extract frames between key points → 30 frames max with guaranteed minimum elbow angle
#
# [1/182] Processing: correct_Copy of push up 100_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 97 frames with pose data
# Minimum elbow angle: 63.7° at frame 78
# Start frame: 22 (angle: 177.2°)
# End frame: 96 (angle: 157.3°)
# Extracting frames from 22 to 96 (total: 75 frames)
# Extracted 75 frames between key points
# ⬇Downsampled from 75 to 30 frames
# Minimum elbow angle frame 78 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 100_flipped_rep_001.mp4
# Success!
#
# [2/182] Processing: correct_Copy of push up 100_rep_001.mp4
# Analyzing frames for key points...
# Found 99 frames with pose data
# Minimum elbow angle: 64.6° at frame 79
# Start frame: 0 (angle: 178.1°)
# End frame: 98 (angle: 156.6°)
# Extracting frames from 0 to 98 (total: 99 frames)
# Extracted 99 frames between key points
# ⬇Downsampled from 99 to 30 frames
# Minimum elbow angle frame 79 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 100_rep_001.mp4
# Success!
#
# [3/182] Processing: correct_Copy of push up 101_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 64.7° at frame 31
# Start frame: 0 (angle: 174.8°)
# End frame: 51 (angle: 156.3°)
# Extracting frames from 0 to 51 (total: 52 frames)
# Extracted 52 frames between key points
# ⬇Downsampled from 52 to 30 frames
# Minimum elbow angle frame 31 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 101_flipped_rep_001.mp4
# Success!
#
# [4/182] Processing: correct_Copy of push up 101_rep_001.mp4
# Analyzing frames for key points...
# Found 53 frames with pose data
# Minimum elbow angle: 62.8° at frame 34
# Start frame: 0 (angle: 176.4°)
# End frame: 52 (angle: 156.3°)
# Extracting frames from 0 to 52 (total: 53 frames)
# Extracted 53 frames between key points
# ⬇Downsampled from 53 to 30 frames
# Minimum elbow angle frame 34 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 101_rep_001.mp4
# Success!
#
# [5/182] Processing: correct_Copy of push up 102_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 60 frames with pose data
# Minimum elbow angle: 64.6° at frame 37
# Start frame: 0 (angle: 172.9°)
# End frame: 59 (angle: 158.0°)
# Extracting frames from 0 to 59 (total: 60 frames)
# Extracted 60 frames between key points
# ⬇Downsampled from 60 to 30 frames
# Minimum elbow angle frame 37 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 102_flipped_rep_001.mp4
# Success!
#
# [6/182] Processing: correct_Copy of push up 102_rep_001.mp4
# Analyzing frames for key points...
# Found 61 frames with pose data
# Minimum elbow angle: 64.4° at frame 43
# Start frame: 0 (angle: 174.2°)
# End frame: 60 (angle: 157.2°)
# Extracting frames from 0 to 60 (total: 61 frames)
# Extracted 61 frames between key points
# ⬇Downsampled from 61 to 30 frames
# Minimum elbow angle frame 43 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 102_rep_001.mp4
# Success!
#
# [7/182] Processing: correct_Copy of push up 113_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 53 frames with pose data
# Minimum elbow angle: 63.8° at frame 32
# Start frame: 0 (angle: 175.2°)
# End frame: 52 (angle: 155.5°)
# Extracting frames from 0 to 52 (total: 53 frames)
# Extracted 53 frames between key points
# ⬇Downsampled from 53 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 113_flipped_rep_001.mp4
# Success!
#
# [8/182] Processing: correct_Copy of push up 113_rep_001.mp4
# Analyzing frames for key points...
# Found 54 frames with pose data
# Minimum elbow angle: 61.6° at frame 37
# Start frame: 0 (angle: 178.5°)
# End frame: 53 (angle: 154.8°)
# Extracting frames from 0 to 53 (total: 54 frames)
# Extracted 54 frames between key points
# ⬇Downsampled from 54 to 30 frames
# Minimum elbow angle frame 37 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 113_rep_001.mp4
# Success!
#
# [9/182] Processing: correct_Copy of push up 114_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 61 frames with pose data
# Minimum elbow angle: 74.9° at frame 39
# Start frame: 0 (angle: 175.1°)
# End frame: 60 (angle: 158.0°)
# Extracting frames from 0 to 60 (total: 61 frames)
# Extracted 61 frames between key points
# ⬇Downsampled from 61 to 30 frames
# Minimum elbow angle frame 39 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 114_flipped_rep_001.mp4
# Success!
#
# [10/182] Processing: correct_Copy of push up 114_rep_001.mp4
# Analyzing frames for key points...
# Found 62 frames with pose data
# Minimum elbow angle: 64.4° at frame 38
# Start frame: 4 (angle: 173.0°)
# End frame: 61 (angle: 156.2°)
# Extracting frames from 4 to 61 (total: 58 frames)
# Extracted 58 frames between key points
# ⬇Downsampled from 58 to 30 frames
# Minimum elbow angle frame 38 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 114_rep_001.mp4
# Success!
#
# [11/182] Processing: correct_Copy of push up 115_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 104 frames with pose data
# Minimum elbow angle: 68.9° at frame 84
# Start frame: 16 (angle: 177.2°)
# End frame: 103 (angle: 157.1°)
# Extracting frames from 16 to 103 (total: 88 frames)
# Extracted 88 frames between key points
# ⬇Downsampled from 88 to 30 frames
# Minimum elbow angle frame 84 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 115_flipped_rep_001.mp4
# Success!
#
# [12/182] Processing: correct_Copy of push up 115_rep_001.mp4
# Analyzing frames for key points...
# Found 105 frames with pose data
# Minimum elbow angle: 55.4° at frame 86
# Start frame: 31 (angle: 179.5°)
# End frame: 104 (angle: 155.1°)
# Extracting frames from 31 to 104 (total: 74 frames)
# Extracted 74 frames between key points
# ⬇Downsampled from 74 to 30 frames
# Minimum elbow angle frame 86 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 115_rep_001.mp4
# Success!
#
# [13/182] Processing: correct_Copy of push up 116_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 31 frames with pose data
# Minimum elbow angle: 55.7° at frame 18
# Start frame: 0 (angle: 172.8°)
# End frame: 30 (angle: 158.0°)
# Extracting frames from 0 to 30 (total: 31 frames)
# Extracted 31 frames between key points
# ⬇Downsampled from 31 to 30 frames
# Minimum elbow angle frame 18 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 116_flipped_rep_001.mp4
# Success!
#
# [14/182] Processing: correct_Copy of push up 116_rep_001.mp4
# Analyzing frames for key points...
# Found 31 frames with pose data
# Minimum elbow angle: 57.5° at frame 20
# Start frame: 0 (angle: 175.4°)
# End frame: 30 (angle: 157.0°)
# Extracting frames from 0 to 30 (total: 31 frames)
# Extracted 31 frames between key points
# ⬇Downsampled from 31 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 116_rep_001.mp4
# Success!
#
# [15/182] Processing: correct_Copy of push up 127_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 73 frames with pose data
# Minimum elbow angle: 52.4° at frame 55
# Start frame: 19 (angle: 175.2°)
# End frame: 72 (angle: 158.2°)
# Extracting frames from 19 to 72 (total: 54 frames)
# Extracted 54 frames between key points
# ⬇Downsampled from 54 to 30 frames
# Minimum elbow angle frame 55 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 127_flipped_rep_001.mp4
# Success!
#
# [16/182] Processing: correct_Copy of push up 127_rep_001.mp4
# Analyzing frames for key points...
# Found 73 frames with pose data
# Minimum elbow angle: 53.7° at frame 52
# Start frame: 0 (angle: 176.8°)
# End frame: 72 (angle: 160.0°)
# Extracting frames from 0 to 72 (total: 73 frames)
# Extracted 73 frames between key points
# ⬇Downsampled from 73 to 30 frames
# Minimum elbow angle frame 52 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 127_rep_001.mp4
# Success!
#
# [17/182] Processing: correct_Copy of push up 129_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 65 frames with pose data
# Minimum elbow angle: 48.1° at frame 43
# Start frame: 5 (angle: 173.9°)
# End frame: 64 (angle: 160.4°)
# Extracting frames from 5 to 64 (total: 60 frames)
# Extracted 60 frames between key points
# ⬇Downsampled from 60 to 30 frames
# Minimum elbow angle frame 43 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 129_flipped_rep_001.mp4
# Success!
#
# [18/182] Processing: correct_Copy of push up 129_rep_001.mp4
# Analyzing frames for key points...
# Found 65 frames with pose data
# Minimum elbow angle: 52.7° at frame 50
# Start frame: 0 (angle: 175.5°)
# End frame: 64 (angle: 163.0°)
# Extracting frames from 0 to 64 (total: 65 frames)
# Extracted 65 frames between key points
# ⬇Downsampled from 65 to 30 frames
# Minimum elbow angle frame 50 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 129_rep_001.mp4
# Success!
#
# [19/182] Processing: correct_Copy of push up 131_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 40 frames with pose data
# Minimum elbow angle: 65.8° at frame 24
# Start frame: 1 (angle: 164.4°)
# End frame: 39 (angle: 159.6°)
# Extracting frames from 1 to 39 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 24 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 131_flipped_rep_001.mp4
# Success!
#
# [20/182] Processing: correct_Copy of push up 131_rep_001.mp4
# Analyzing frames for key points...
# Found 40 frames with pose data
# Minimum elbow angle: 62.8° at frame 23
# Start frame: 1 (angle: 161.7°)
# End frame: 39 (angle: 158.8°)
# Extracting frames from 1 to 39 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 23 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 131_rep_001.mp4
# Success!
#
# [21/182] Processing: correct_Copy of push up 132_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 41 frames with pose data
# Minimum elbow angle: 68.9° at frame 26
# Start frame: 3 (angle: 164.1°)
# End frame: 40 (angle: 155.5°)
# Extracting frames from 3 to 40 (total: 38 frames)
# Extracted 38 frames between key points
# ⬇Downsampled from 38 to 30 frames
# Minimum elbow angle frame 26 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 132_flipped_rep_001.mp4
# Success!
#
# [22/182] Processing: correct_Copy of push up 132_rep_001.mp4
# Analyzing frames for key points...
# Found 42 frames with pose data
# Minimum elbow angle: 64.1° at frame 26
# Start frame: 3 (angle: 160.8°)
# End frame: 41 (angle: 161.2°)
# Extracting frames from 3 to 41 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 26 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 132_rep_001.mp4
# Success!
#
# [23/182] Processing: correct_Copy of push up 133_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 62.3° at frame 24
# Start frame: 1 (angle: 163.3°)
# End frame: 38 (angle: 160.7°)
# Extracting frames from 1 to 38 (total: 38 frames)
# Extracted 38 frames between key points
# ⬇Downsampled from 38 to 30 frames
# Minimum elbow angle frame 24 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 133_flipped_rep_001.mp4
# Success!
#
# [24/182] Processing: correct_Copy of push up 133_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 62.6° at frame 22
# Start frame: 0 (angle: 162.5°)
# End frame: 38 (angle: 160.3°)
# Extracting frames from 0 to 38 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 22 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 133_rep_001.mp4
# Success!
#
# [25/182] Processing: correct_Copy of push up 134_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 38 frames with pose data
# Minimum elbow angle: 66.1° at frame 22
# Start frame: 1 (angle: 164.9°)
# End frame: 37 (angle: 158.6°)
# Extracting frames from 1 to 37 (total: 37 frames)
# Extracted 37 frames between key points
# ⬇Downsampled from 37 to 30 frames
# Minimum elbow angle frame 22 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 134_flipped_rep_001.mp4
# Success!
#
# [26/182] Processing: correct_Copy of push up 134_rep_001.mp4
# Analyzing frames for key points...
# Found 38 frames with pose data
# Minimum elbow angle: 64.4° at frame 20
# Start frame: 1 (angle: 161.9°)
# End frame: 37 (angle: 158.3°)
# Extracting frames from 1 to 37 (total: 37 frames)
# Extracted 37 frames between key points
# ⬇Downsampled from 37 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 134_rep_001.mp4
# Success!
#
# [27/182] Processing: correct_Copy of push up 135_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 60.5° at frame 20
# Start frame: 0 (angle: 161.8°)
# End frame: 33 (angle: 157.7°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 135_flipped_rep_001.mp4
# Success!
#
# [28/182] Processing: correct_Copy of push up 135_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 61.9° at frame 20
# Start frame: 1 (angle: 159.8°)
# End frame: 33 (angle: 158.9°)
# Extracting frames from 1 to 33 (total: 33 frames)
# Extracted 33 frames between key points
# ⬇Downsampled from 33 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 135_rep_001.mp4
# Success!
#
# [29/182] Processing: correct_Copy of push up 136_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 36 frames with pose data
# Minimum elbow angle: 63.7° at frame 20
# Start frame: 1 (angle: 162.6°)
# End frame: 35 (angle: 156.3°)
# Extracting frames from 1 to 35 (total: 35 frames)
# Extracted 35 frames between key points
# ⬇Downsampled from 35 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 136_flipped_rep_001.mp4
# Success!
#
# [30/182] Processing: correct_Copy of push up 136_rep_001.mp4
# Analyzing frames for key points...
# Found 37 frames with pose data
# Minimum elbow angle: 65.2° at frame 21
# Start frame: 1 (angle: 160.2°)
# End frame: 36 (angle: 159.2°)
# Extracting frames from 1 to 36 (total: 36 frames)
# Extracted 36 frames between key points
# ⬇Downsampled from 36 to 30 frames
# Minimum elbow angle frame 21 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 136_rep_001.mp4
# Success!
#
# [31/182] Processing: correct_Copy of push up 137_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 63.2° at frame 18
# Start frame: 0 (angle: 155.2°)
# End frame: 33 (angle: 157.0°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 18 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 137_rep_001.mp4
# Success!
#
# [32/182] Processing: correct_Copy of push up 138_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 36 frames with pose data
# Minimum elbow angle: 66.4° at frame 20
# Start frame: 1 (angle: 160.4°)
# End frame: 35 (angle: 156.8°)
# Extracting frames from 1 to 35 (total: 35 frames)
# Extracted 35 frames between key points
# ⬇Downsampled from 35 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 138_flipped_rep_001.mp4
# Success!
#
# [33/182] Processing: correct_Copy of push up 138_rep_001.mp4
# Analyzing frames for key points...
# Found 36 frames with pose data
# Minimum elbow angle: 61.9° at frame 19
# Start frame: 0 (angle: 158.9°)
# End frame: 35 (angle: 157.3°)
# Extracting frames from 0 to 35 (total: 36 frames)
# Extracted 36 frames between key points
# ⬇Downsampled from 36 to 30 frames
# Minimum elbow angle frame 19 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 138_rep_001.mp4
# Success!
#
# [34/182] Processing: correct_Copy of push up 140_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 48 frames with pose data
# Minimum elbow angle: 63.9° at frame 32
# Start frame: 1 (angle: 161.5°)
# End frame: 47 (angle: 155.2°)
# Extracting frames from 1 to 47 (total: 47 frames)
# Extracted 47 frames between key points
# ⬇Downsampled from 47 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 140_flipped_rep_001.mp4
# Success!
#
# [35/182] Processing: correct_Copy of push up 140_rep_001.mp4
# Analyzing frames for key points...
# Found 48 frames with pose data
# Minimum elbow angle: 63.5° at frame 32
# Start frame: 0 (angle: 157.5°)
# End frame: 47 (angle: 156.8°)
# Extracting frames from 0 to 47 (total: 48 frames)
# Extracted 48 frames between key points
# ⬇Downsampled from 48 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 140_rep_001.mp4
# Success!
#
# [36/182] Processing: correct_Copy of push up 141_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 57.6° at frame 37
# Start frame: 4 (angle: 167.0°)
# End frame: 51 (angle: 156.0°)
# Extracting frames from 4 to 51 (total: 48 frames)
# Extracted 48 frames between key points
# ⬇Downsampled from 48 to 30 frames
# Minimum elbow angle frame 37 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 141_flipped_rep_001.mp4
# Success!
#
# [37/182] Processing: correct_Copy of push up 141_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 59.9° at frame 35
# Start frame: 1 (angle: 164.9°)
# End frame: 51 (angle: 154.9°)
# Extracting frames from 1 to 51 (total: 51 frames)
# Extracted 51 frames between key points
# ⬇Downsampled from 51 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 141_rep_001.mp4
# Success!
#
# [38/182] Processing: correct_Copy of push up 142_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 53 frames with pose data
# Minimum elbow angle: 56.2° at frame 36
# Start frame: 3 (angle: 164.4°)
# End frame: 52 (angle: 160.6°)
# Extracting frames from 3 to 52 (total: 50 frames)
# Extracted 50 frames between key points
# ⬇Downsampled from 50 to 30 frames
# Minimum elbow angle frame 36 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 142_flipped_rep_001.mp4
# Success!
#
# [39/182] Processing: correct_Copy of push up 142_rep_001.mp4
# Analyzing frames for key points...
# Found 53 frames with pose data
# Minimum elbow angle: 58.1° at frame 35
# Start frame: 0 (angle: 163.2°)
# End frame: 52 (angle: 161.0°)
# Extracting frames from 0 to 52 (total: 53 frames)
# Extracted 53 frames between key points
# ⬇Downsampled from 53 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 142_rep_001.mp4
# Success!
#
# [40/182] Processing: correct_Copy of push up 144_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 51 frames with pose data
# Minimum elbow angle: 66.0° at frame 32
# Start frame: 3 (angle: 169.0°)
# End frame: 50 (angle: 161.5°)
# Extracting frames from 3 to 50 (total: 48 frames)
# Extracted 48 frames between key points
# ⬇Downsampled from 48 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 144_flipped_rep_001.mp4
# Success!
#
# [41/182] Processing: correct_Copy of push up 144_rep_001.mp4
# Analyzing frames for key points...
# Found 50 frames with pose data
# Minimum elbow angle: 63.6° at frame 31
# Start frame: 4 (angle: 166.5°)
# End frame: 49 (angle: 155.5°)
# Extracting frames from 4 to 49 (total: 46 frames)
# Extracted 46 frames between key points
# ⬇Downsampled from 46 to 30 frames
# Minimum elbow angle frame 31 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 144_rep_001.mp4
# Success!
#
# [42/182] Processing: correct_Copy of push up 146_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 60 frames with pose data
# Minimum elbow angle: 64.8° at frame 32
# Start frame: 0 (angle: 167.4°)
# End frame: 59 (angle: 158.2°)
# Extracting frames from 0 to 59 (total: 60 frames)
# Extracted 60 frames between key points
# ⬇Downsampled from 60 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 146_flipped_rep_001.mp4
# Success!
#
# [43/182] Processing: correct_Copy of push up 146_rep_001.mp4
# Analyzing frames for key points...
# Found 60 frames with pose data
# Minimum elbow angle: 55.2° at frame 33
# Start frame: 1 (angle: 166.4°)
# End frame: 59 (angle: 157.3°)
# Extracting frames from 1 to 59 (total: 59 frames)
# Extracted 59 frames between key points
# ⬇Downsampled from 59 to 30 frames
# Minimum elbow angle frame 33 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 146_rep_001.mp4
# Success!
#
# [44/182] Processing: correct_Copy of push up 147_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 77 frames with pose data
# Minimum elbow angle: 67.6° at frame 46
# Start frame: 0 (angle: 174.1°)
# End frame: 76 (angle: 155.6°)
# Extracting frames from 0 to 76 (total: 77 frames)
# Extracted 77 frames between key points
# ⬇Downsampled from 77 to 30 frames
# Minimum elbow angle frame 46 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 147_flipped_rep_001.mp4
# Success!
#
# [45/182] Processing: correct_Copy of push up 147_rep_001.mp4
# Analyzing frames for key points...
# Found 77 frames with pose data
# Minimum elbow angle: 57.1° at frame 57
# Start frame: 9 (angle: 173.2°)
# End frame: 76 (angle: 155.5°)
# Extracting frames from 9 to 76 (total: 68 frames)
# Extracted 68 frames between key points
# ⬇Downsampled from 68 to 30 frames
# Minimum elbow angle frame 57 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 147_rep_001.mp4
# Success!
#
# [46/182] Processing: correct_Copy of push up 148_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 89 frames with pose data
# Minimum elbow angle: 68.7° at frame 68
# Start frame: 0 (angle: 174.2°)
# End frame: 88 (angle: 155.2°)
# Extracting frames from 0 to 88 (total: 89 frames)
# Extracted 89 frames between key points
# ⬇Downsampled from 89 to 30 frames
# Minimum elbow angle frame 68 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 148_flipped_rep_001.mp4
# Success!
#
# [47/182] Processing: correct_Copy of push up 148_rep_001.mp4
# Analyzing frames for key points...
# Found 90 frames with pose data
# Minimum elbow angle: 58.8° at frame 67
# Start frame: 3 (angle: 173.1°)
# End frame: 89 (angle: 155.8°)
# Extracting frames from 3 to 89 (total: 87 frames)
# Extracted 87 frames between key points
# ⬇Downsampled from 87 to 30 frames
# Minimum elbow angle frame 67 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 148_rep_001.mp4
# Success!
#
# [48/182] Processing: correct_Copy of push up 162_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 58 frames with pose data
# Minimum elbow angle: 51.9° at frame 30
# Start frame: 0 (angle: 167.9°)
# End frame: 57 (angle: 156.5°)
# Extracting frames from 0 to 57 (total: 58 frames)
# Extracted 58 frames between key points
# ⬇Downsampled from 58 to 30 frames
# Minimum elbow angle frame 30 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 162_flipped_rep_001.mp4
# Success!
#
# [49/182] Processing: correct_Copy of push up 162_rep_001.mp4
# Analyzing frames for key points...
# Found 59 frames with pose data
# Minimum elbow angle: 47.6° at frame 39
# Start frame: 0 (angle: 168.0°)
# End frame: 58 (angle: 158.3°)
# Extracting frames from 0 to 58 (total: 59 frames)
# Extracted 59 frames between key points
# ⬇Downsampled from 59 to 30 frames
# Minimum elbow angle frame 39 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 162_rep_001.mp4
# Success!
#
# [50/182] Processing: correct_Copy of push up 163_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 57 frames with pose data
# Minimum elbow angle: 54.1° at frame 26
# Start frame: 0 (angle: 161.4°)
# End frame: 56 (angle: 155.7°)
# Extracting frames from 0 to 56 (total: 57 frames)
# Extracted 57 frames between key points
# ⬇Downsampled from 57 to 30 frames
# Minimum elbow angle frame 26 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 163_flipped_rep_001.mp4
# Success!
#
# [51/182] Processing: correct_Copy of push up 163_rep_001.mp4
# Analyzing frames for key points...
# Found 58 frames with pose data
# Minimum elbow angle: 49.6° at frame 37
# Start frame: 0 (angle: 160.7°)
# End frame: 57 (angle: 157.9°)
# Extracting frames from 0 to 57 (total: 58 frames)
# Extracted 58 frames between key points
# ⬇Downsampled from 58 to 30 frames
# Minimum elbow angle frame 37 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 163_rep_001.mp4
# Success!
#
# [52/182] Processing: correct_Copy of push up 164_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 64 frames with pose data
# Minimum elbow angle: 48.5° at frame 43
# Start frame: 0 (angle: 169.9°)
# End frame: 63 (angle: 156.5°)
# Extracting frames from 0 to 63 (total: 64 frames)
# Extracted 64 frames between key points
# ⬇Downsampled from 64 to 30 frames
# Minimum elbow angle frame 43 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 164_flipped_rep_001.mp4
# Success!
#
# [53/182] Processing: correct_Copy of push up 164_rep_001.mp4
# Analyzing frames for key points...
# Found 65 frames with pose data
# Minimum elbow angle: 46.7° at frame 42
# Start frame: 0 (angle: 169.3°)
# End frame: 64 (angle: 158.2°)
# Extracting frames from 0 to 64 (total: 65 frames)
# Extracted 65 frames between key points
# ⬇Downsampled from 65 to 30 frames
# Minimum elbow angle frame 42 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 164_rep_001.mp4
# Success!
#
# [54/182] Processing: correct_Copy of push up 165_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 59 frames with pose data
# Minimum elbow angle: 49.4° at frame 37
# Start frame: 0 (angle: 167.5°)
# End frame: 58 (angle: 155.0°)
# Extracting frames from 0 to 58 (total: 59 frames)
# Extracted 59 frames between key points
# ⬇Downsampled from 59 to 30 frames
# Minimum elbow angle frame 37 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 165_flipped_rep_001.mp4
# Success!
#
# [55/182] Processing: correct_Copy of push up 165_rep_001.mp4
# Analyzing frames for key points...
# Found 60 frames with pose data
# Minimum elbow angle: 46.8° at frame 35
# Start frame: 0 (angle: 167.8°)
# End frame: 59 (angle: 158.0°)
# Extracting frames from 0 to 59 (total: 60 frames)
# Extracted 60 frames between key points
# ⬇Downsampled from 60 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 165_rep_001.mp4
# Success!
#
# [56/182] Processing: correct_Copy of push up 173_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 100 frames with pose data
# Minimum elbow angle: 85.5° at frame 75
# Start frame: 0 (angle: 173.2°)
# End frame: 99 (angle: 155.1°)
# Extracting frames from 0 to 99 (total: 100 frames)
# Extracted 100 frames between key points
# ⬇Downsampled from 100 to 30 frames
# Minimum elbow angle frame 75 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 173_flipped_rep_001.mp4
# Success!
#
# [57/182] Processing: correct_Copy of push up 173_rep_001.mp4
# Analyzing frames for key points...
# Found 100 frames with pose data
# Minimum elbow angle: 75.1° at frame 74
# Start frame: 4 (angle: 173.7°)
# End frame: 99 (angle: 158.2°)
# Extracting frames from 4 to 99 (total: 96 frames)
# Extracted 96 frames between key points
# ⬇Downsampled from 96 to 30 frames
# Minimum elbow angle frame 74 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 173_rep_001.mp4
# Success!
#
# [58/182] Processing: correct_Copy of push up 174_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 78 frames with pose data
# Minimum elbow angle: 92.9° at frame 60
# Start frame: 0 (angle: 166.6°)
# End frame: 77 (angle: 155.5°)
# Extracting frames from 0 to 77 (total: 78 frames)
# Extracted 78 frames between key points
# ⬇Downsampled from 78 to 30 frames
# Minimum elbow angle frame 60 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 174_flipped_rep_001.mp4
# Success!
#
# [59/182] Processing: correct_Copy of push up 174_rep_001.mp4
# Analyzing frames for key points...
# Found 78 frames with pose data
# Minimum elbow angle: 83.0° at frame 50
# Start frame: 0 (angle: 169.9°)
# End frame: 77 (angle: 157.3°)
# Extracting frames from 0 to 77 (total: 78 frames)
# Extracted 78 frames between key points
# ⬇Downsampled from 78 to 30 frames
# Minimum elbow angle frame 50 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 174_rep_001.mp4
# Success!
#
# [60/182] Processing: correct_Copy of push up 175_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 57 frames with pose data
# Minimum elbow angle: 100.4° at frame 41
# Start frame: 0 (angle: 171.8°)
# End frame: 56 (angle: 156.7°)
# Extracting frames from 0 to 56 (total: 57 frames)
# Extracted 57 frames between key points
# ⬇Downsampled from 57 to 30 frames
# Minimum elbow angle frame 41 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 175_flipped_rep_001.mp4
# Success!
#
# [61/182] Processing: correct_Copy of push up 175_rep_001.mp4
# Analyzing frames for key points...
# Found 57 frames with pose data
# Minimum elbow angle: 87.3° at frame 35
# Start frame: 0 (angle: 172.9°)
# End frame: 56 (angle: 157.6°)
# Extracting frames from 0 to 56 (total: 57 frames)
# Extracted 57 frames between key points
# ⬇Downsampled from 57 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 175_rep_001.mp4
# Success!
#
# [62/182] Processing: correct_Copy of push up 177_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 94 frames with pose data
# Minimum elbow angle: 63.0° at frame 69
# Start frame: 0 (angle: 176.8°)
# End frame: 93 (angle: 155.7°)
# Extracting frames from 0 to 93 (total: 94 frames)
# Extracted 94 frames between key points
# ⬇Downsampled from 94 to 30 frames
# Minimum elbow angle frame 69 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 177_flipped_rep_001.mp4
# Success!
#
# [63/182] Processing: correct_Copy of push up 177_rep_001.mp4
# Analyzing frames for key points...
# Found 94 frames with pose data
# Minimum elbow angle: 62.1° at frame 66
# Start frame: 2 (angle: 176.1°)
# End frame: 93 (angle: 156.5°)
# Extracting frames from 2 to 93 (total: 92 frames)
# Extracted 92 frames between key points
# ⬇Downsampled from 92 to 30 frames
# Minimum elbow angle frame 66 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 177_rep_001.mp4
# Success!
#
# [64/182] Processing: correct_Copy of push up 178_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 100 frames with pose data
# Minimum elbow angle: 63.9° at frame 71
# Start frame: 12 (angle: 175.1°)
# End frame: 99 (angle: 156.3°)
# Extracting frames from 12 to 99 (total: 88 frames)
# Extracted 88 frames between key points
# ⬇Downsampled from 88 to 30 frames
# Minimum elbow angle frame 71 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 178_flipped_rep_001.mp4
# Success!
#
# [65/182] Processing: correct_Copy of push up 178_rep_001.mp4
# Analyzing frames for key points...
# Found 101 frames with pose data
# Minimum elbow angle: 63.1° at frame 77
# Start frame: 0 (angle: 175.7°)
# End frame: 100 (angle: 159.1°)
# Extracting frames from 0 to 100 (total: 101 frames)
# Extracted 101 frames between key points
# ⬇Downsampled from 101 to 30 frames
# Minimum elbow angle frame 77 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 178_rep_001.mp4
# Success!
#
# [66/182] Processing: correct_Copy of push up 186_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 60.3° at frame 43
# Start frame: 0 (angle: 176.8°)
# End frame: 51 (angle: 161.8°)
# Extracting frames from 0 to 51 (total: 52 frames)
# Extracted 52 frames between key points
# ⬇Downsampled from 52 to 30 frames
# Minimum elbow angle frame 43 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 186_flipped_rep_001.mp4
# Success!
#
# [67/182] Processing: correct_Copy of push up 186_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 67.9° at frame 33
# Start frame: 17 (angle: 177.1°)
# End frame: 51 (angle: 161.0°)
# Extracting frames from 17 to 51 (total: 35 frames)
# Extracted 35 frames between key points
# ⬇Downsampled from 35 to 30 frames
# Minimum elbow angle frame 33 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 186_rep_001.mp4
# Success!
#
# [68/182] Processing: correct_Copy of push up 187_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 55 frames with pose data
# Minimum elbow angle: 58.1° at frame 35
# Start frame: 0 (angle: 173.4°)
# End frame: 54 (angle: 163.7°)
# Extracting frames from 0 to 54 (total: 55 frames)
# Extracted 55 frames between key points
# ⬇Downsampled from 55 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 187_flipped_rep_001.mp4
# Success!
#
# [69/182] Processing: correct_Copy of push up 187_rep_001.mp4
# Analyzing frames for key points...
# Found 55 frames with pose data
# Minimum elbow angle: 53.2° at frame 34
# Start frame: 0 (angle: 176.0°)
# End frame: 54 (angle: 162.9°)
# Extracting frames from 0 to 54 (total: 55 frames)
# Extracted 55 frames between key points
# ⬇Downsampled from 55 to 30 frames
# Minimum elbow angle frame 34 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 187_rep_001.mp4
# Success!
#
# [70/182] Processing: correct_Copy of push up 188_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 56 frames with pose data
# Minimum elbow angle: 57.3° at frame 38
# Start frame: 13 (angle: 172.7°)
# End frame: 55 (angle: 163.8°)
# Extracting frames from 13 to 55 (total: 43 frames)
# Extracted 43 frames between key points
# ⬇Downsampled from 43 to 30 frames
# Minimum elbow angle frame 38 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 188_flipped_rep_001.mp4
# Success!
#
# [71/182] Processing: correct_Copy of push up 188_rep_001.mp4
# Analyzing frames for key points...
# Found 56 frames with pose data
# Minimum elbow angle: 63.7° at frame 33
# Start frame: 15 (angle: 174.4°)
# End frame: 55 (angle: 161.7°)
# Extracting frames from 15 to 55 (total: 41 frames)
# Extracted 41 frames between key points
# ⬇Downsampled from 41 to 30 frames
# Minimum elbow angle frame 33 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 188_rep_001.mp4
# Success!
#
# [72/182] Processing: correct_Copy of push up 197_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 106 frames with pose data
# Minimum elbow angle: 78.0° at frame 71
# Start frame: 0 (angle: 171.0°)
# End frame: 105 (angle: 155.7°)
# Extracting frames from 0 to 105 (total: 106 frames)
# Extracted 106 frames between key points
# ⬇Downsampled from 106 to 30 frames
# Minimum elbow angle frame 71 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 197_flipped_rep_001.mp4
# Success!
#
# [73/182] Processing: correct_Copy of push up 197_rep_001.mp4
# Analyzing frames for key points...
# Found 108 frames with pose data
# Minimum elbow angle: 78.0° at frame 76
# Start frame: 0 (angle: 167.1°)
# End frame: 107 (angle: 155.9°)
# Extracting frames from 0 to 107 (total: 108 frames)
# Extracted 108 frames between key points
# ⬇Downsampled from 108 to 30 frames
# Minimum elbow angle frame 76 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 197_rep_001.mp4
# Success!
#
# [74/182] Processing: correct_Copy of push up 2_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 36 frames with pose data
# Minimum elbow angle: 106.1° at frame 22
# Start frame: 2 (angle: 175.1°)
# End frame: 35 (angle: 157.0°)
# Extracting frames from 2 to 35 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 22 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 2_flipped_rep_001.mp4
# Success!
#
# [75/182] Processing: correct_Copy of push up 2_rep_001.mp4
# Analyzing frames for key points...
# Found 36 frames with pose data
# Minimum elbow angle: 105.0° at frame 25
# Start frame: 3 (angle: 175.5°)
# End frame: 35 (angle: 155.6°)
# Extracting frames from 3 to 35 (total: 33 frames)
# Extracted 33 frames between key points
# ⬇Downsampled from 33 to 30 frames
# Minimum elbow angle frame 25 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 2_rep_001.mp4
# Success!
#
# [76/182] Processing: correct_Copy of push up 3_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 106.1° at frame 19
# Start frame: 0 (angle: 174.5°)
# End frame: 33 (angle: 157.2°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 19 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 3_flipped_rep_001.mp4
# Success!
#
# [77/182] Processing: correct_Copy of push up 3_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 108.3° at frame 20
# Start frame: 0 (angle: 174.3°)
# End frame: 33 (angle: 158.7°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 20 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 3_rep_001.mp4
# Success!
#
# [78/182] Processing: correct_Copy of push up 47_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 50 frames with pose data
# Minimum elbow angle: 66.2° at frame 26
# Start frame: 0 (angle: 174.5°)
# End frame: 49 (angle: 161.9°)
# Extracting frames from 0 to 49 (total: 50 frames)
# Extracted 50 frames between key points
# ⬇Downsampled from 50 to 30 frames
# Minimum elbow angle frame 26 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 47_flipped_rep_001.mp4
# Success!
#
# [79/182] Processing: correct_Copy of push up 47_rep_001.mp4
# Analyzing frames for key points...
# Found 50 frames with pose data
# Minimum elbow angle: 67.7° at frame 25
# Start frame: 0 (angle: 175.3°)
# End frame: 49 (angle: 156.2°)
# Extracting frames from 0 to 49 (total: 50 frames)
# Extracted 50 frames between key points
# ⬇Downsampled from 50 to 30 frames
# Minimum elbow angle frame 25 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 47_rep_001.mp4
# Success!
#
# [80/182] Processing: correct_Copy of push up 4_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 102.9° at frame 23
# Start frame: 0 (angle: 172.7°)
# End frame: 38 (angle: 158.4°)
# Extracting frames from 0 to 38 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 23 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 4_flipped_rep_001.mp4
# Success!
#
# [81/182] Processing: correct_Copy of push up 4_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 100.4° at frame 21
# Start frame: 4 (angle: 172.0°)
# End frame: 38 (angle: 158.7°)
# Extracting frames from 4 to 38 (total: 35 frames)
# Extracted 35 frames between key points
# ⬇Downsampled from 35 to 30 frames
# Minimum elbow angle frame 21 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 4_rep_001.mp4
# Success!
#
# [82/182] Processing: correct_Copy of push up 5_rep_001.mp4
# Analyzing frames for key points...
# Found 31 frames with pose data
# Minimum elbow angle: 104.4° at frame 17
# Start frame: 0 (angle: 173.1°)
# End frame: 30 (angle: 156.6°)
# Extracting frames from 0 to 30 (total: 31 frames)
# Extracted 31 frames between key points
# ⬇Downsampled from 31 to 30 frames
# Minimum elbow angle frame 17 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 5_rep_001.mp4
# Success!
#
# [83/182] Processing: correct_Copy of push up 6_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 37 frames with pose data
# Minimum elbow angle: 105.7° at frame 23
# Start frame: 0 (angle: 174.8°)
# End frame: 36 (angle: 156.4°)
# Extracting frames from 0 to 36 (total: 37 frames)
# Extracted 37 frames between key points
# ⬇Downsampled from 37 to 30 frames
# Minimum elbow angle frame 23 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 6_flipped_rep_001.mp4
# Success!
#
# [84/182] Processing: correct_Copy of push up 6_rep_001.mp4
# Analyzing frames for key points...
# Found 37 frames with pose data
# Minimum elbow angle: 103.6° at frame 21
# Start frame: 0 (angle: 173.6°)
# End frame: 36 (angle: 155.7°)
# Extracting frames from 0 to 36 (total: 37 frames)
# Extracted 37 frames between key points
# ⬇Downsampled from 37 to 30 frames
# Minimum elbow angle frame 21 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 6_rep_001.mp4
# Success!
#
# [85/182] Processing: correct_Copy of push up 79_rep_001.mp4
# Analyzing frames for key points...
# Found 29 frames with pose data
# Minimum elbow angle: 103.5° at frame 25
# Start frame: 9 (angle: 179.4°)
# End frame: 28 (angle: 159.3°)
# Extracting frames from 9 to 28 (total: 20 frames)
# Extracted 20 frames between key points
# Using all 20 frames (≤30)
# Saved 20 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 79_rep_001.mp4
# Success!
#
# [86/182] Processing: correct_Copy of push up 7_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 108.2° at frame 19
# Start frame: 0 (angle: 174.7°)
# End frame: 33 (angle: 154.8°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 19 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_correct_Copy of push up 7_rep_001.mp4
# Success!
#
# [87/182] Processing: correct_Copy of push up 80_flipped_rep_001.mp4
# Analyzing frames for key points...
# ...
# Success!
#
# [155/182] Processing: incorrect_Copy of push up 152_rep_001.mp4
# Analyzing frames for key points...
# Found 46 frames with pose data
# Minimum elbow angle: 82.9° at frame 32
# Start frame: 9 (angle: 176.3°)
# End frame: 48 (angle: 156.4°)
# Extracting frames from 9 to 48 (total: 40 frames)
# Extracted 40 frames between key points
# ⬇Downsampled from 40 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 152_rep_001.mp4
# Success!
#
# [156/182] Processing: incorrect_Copy of push up 153_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 45 frames with pose data
# Minimum elbow angle: 106.7° at frame 29
# Start frame: 0 (angle: 170.9°)
# End frame: 44 (angle: 155.4°)
# Extracting frames from 0 to 44 (total: 45 frames)
# Extracted 45 frames between key points
# ⬇Downsampled from 45 to 30 frames
# Minimum elbow angle frame 29 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 153_flipped_rep_001.mp4
# Success!
#
# [157/182] Processing: incorrect_Copy of push up 153_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 100.7° at frame 29
# Start frame: 5 (angle: 172.1°)
# End frame: 45 (angle: 155.5°)
# Extracting frames from 5 to 45 (total: 41 frames)
# Extracted 41 frames between key points
# ⬇Downsampled from 41 to 30 frames
# Minimum elbow angle frame 29 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 153_rep_001.mp4
# Success!
#
# [158/182] Processing: incorrect_Copy of push up 155_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 45 frames with pose data
# Minimum elbow angle: 81.6° at frame 28
# Start frame: 4 (angle: 169.7°)
# End frame: 44 (angle: 157.7°)
# Extracting frames from 4 to 44 (total: 41 frames)
# Extracted 41 frames between key points
# ⬇Downsampled from 41 to 30 frames
# Minimum elbow angle frame 28 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 155_flipped_rep_001.mp4
# Success!
#
# [159/182] Processing: incorrect_Copy of push up 155_rep_001.mp4
# Analyzing frames for key points...
# Found 43 frames with pose data
# Minimum elbow angle: 96.6° at frame 31
# Start frame: 0 (angle: 171.1°)
# End frame: 42 (angle: 155.9°)
# Extracting frames from 0 to 42 (total: 43 frames)
# Extracted 43 frames between key points
# ⬇Downsampled from 43 to 30 frames
# Minimum elbow angle frame 31 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 155_rep_001.mp4
# Success!
#
# [160/182] Processing: incorrect_Copy of push up 156_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 41 frames with pose data
# Minimum elbow angle: 83.7° at frame 21
# Start frame: 0 (angle: 165.6°)
# End frame: 40 (angle: 158.4°)
# Extracting frames from 0 to 40 (total: 41 frames)
# Extracted 41 frames between key points
# ⬇Downsampled from 41 to 30 frames
# Minimum elbow angle frame 21 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 156_flipped_rep_001.mp4
# Success!
#
# [161/182] Processing: incorrect_Copy of push up 156_rep_001.mp4
# Analyzing frames for key points...
# Found 39 frames with pose data
# Minimum elbow angle: 92.5° at frame 25
# Start frame: 0 (angle: 165.8°)
# End frame: 38 (angle: 155.9°)
# Extracting frames from 0 to 38 (total: 39 frames)
# Extracted 39 frames between key points
# ⬇Downsampled from 39 to 30 frames
# Minimum elbow angle frame 25 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 156_rep_001.mp4
# Success!
#
# [162/182] Processing: incorrect_Copy of push up 171_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 206 frames with pose data
# Minimum elbow angle: 101.2° at frame 193
# Start frame: 18 (angle: 178.5°)
# End frame: 205 (angle: 156.8°)
# Extracting frames from 18 to 205 (total: 188 frames)
# Extracted 188 frames between key points
# ⬇Downsampled from 188 to 30 frames
# Minimum elbow angle frame 193 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 171_flipped_rep_001.mp4
# Success!
#
# [163/182] Processing: incorrect_Copy of push up 198_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 163 frames with pose data
# Minimum elbow angle: 65.1° at frame 27
# Start frame: 0 (angle: 161.3°)
# End frame: 162 (angle: 155.5°)
# Extracting frames from 0 to 162 (total: 163 frames)
# Extracted 163 frames between key points
# ⬇Downsampled from 163 to 30 frames
# Minimum elbow angle frame 27 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 198_flipped_rep_001.mp4
# Success!
#
# [164/182] Processing: incorrect_Copy of push up 198_rep_001.mp4
# Analyzing frames for key points...
# Found 167 frames with pose data
# Minimum elbow angle: 65.0° at frame 27
# Start frame: 0 (angle: 162.4°)
# End frame: 166 (angle: 157.3°)
# Extracting frames from 0 to 166 (total: 167 frames)
# Extracted 167 frames between key points
# ⬇Downsampled from 167 to 30 frames
# Minimum elbow angle frame 27 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 198_rep_001.mp4
# Success!
#
# [165/182] Processing: incorrect_Copy of push up 36_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 65 frames with pose data
# Minimum elbow angle: 46.5° at frame 43
# Start frame: 6 (angle: 178.6°)
# End frame: 64 (angle: 153.5°)
# Extracting frames from 6 to 64 (total: 59 frames)
# Extracted 59 frames between key points
# ⬇Downsampled from 59 to 30 frames
# Minimum elbow angle frame 43 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 36_flipped_rep_001.mp4
# Success!
#
# [166/182] Processing: incorrect_Copy of push up 36_rep_001.mp4
# Analyzing frames for key points...
# Found 66 frames with pose data
# Minimum elbow angle: 46.2° at frame 52
# Start frame: 11 (angle: 175.6°)
# End frame: 65 (angle: 159.0°)
# Extracting frames from 11 to 65 (total: 55 frames)
# Extracted 55 frames between key points
# ⬇Downsampled from 55 to 30 frames
# Minimum elbow angle frame 52 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 36_rep_001.mp4
# Success!
#
# [167/182] Processing: incorrect_Copy of push up 37_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 55 frames with pose data
# Minimum elbow angle: 49.6° at frame 35
# Start frame: 3 (angle: 178.0°)
# End frame: 54 (angle: 157.5°)
# Extracting frames from 3 to 54 (total: 52 frames)
# Extracted 52 frames between key points
# ⬇Downsampled from 52 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 37_flipped_rep_001.mp4
# Success!
#
# [168/182] Processing: incorrect_Copy of push up 37_rep_001.mp4
# Analyzing frames for key points...
# Found 55 frames with pose data
# Minimum elbow angle: 47.8° at frame 36
# Start frame: 0 (angle: 178.9°)
# End frame: 54 (angle: 156.1°)
# Extracting frames from 0 to 54 (total: 55 frames)
# Extracted 55 frames between key points
# ⬇Downsampled from 55 to 30 frames
# Minimum elbow angle frame 36 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 37_rep_001.mp4
# Success!
#
# [169/182] Processing: incorrect_Copy of push up 42_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 66 frames with pose data
# Minimum elbow angle: 55.7° at frame 41
# Start frame: 0 (angle: 163.1°)
# End frame: 65 (angle: 154.9°)
# Extracting frames from 0 to 65 (total: 66 frames)
# Extracted 66 frames between key points
# ⬇Downsampled from 66 to 30 frames
# Minimum elbow angle frame 41 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 42_flipped_rep_001.mp4
# Success!
#
# [170/182] Processing: incorrect_Copy of push up 42_rep_001.mp4
# Analyzing frames for key points...
# Found 67 frames with pose data
# Minimum elbow angle: 50.1° at frame 44
# Start frame: 0 (angle: 160.3°)
# End frame: 66 (angle: 155.7°)
# Extracting frames from 0 to 66 (total: 67 frames)
# Extracted 67 frames between key points
# ⬇Downsampled from 67 to 30 frames
# Minimum elbow angle frame 44 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 42_rep_001.mp4
# Success!
#
# [171/182] Processing: incorrect_Copy of push up 44_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 48 frames with pose data
# Minimum elbow angle: 60.6° at frame 28
# Start frame: 1 (angle: 169.5°)
# End frame: 47 (angle: 155.6°)
# Extracting frames from 1 to 47 (total: 47 frames)
# Extracted 47 frames between key points
# ⬇Downsampled from 47 to 30 frames
# Minimum elbow angle frame 28 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 44_flipped_rep_001.mp4
# Success!
#
# [172/182] Processing: incorrect_Copy of push up 44_rep_001.mp4
# Analyzing frames for key points...
# Found 50 frames with pose data
# Minimum elbow angle: 65.3° at frame 26
# Start frame: 0 (angle: 169.4°)
# End frame: 49 (angle: 159.0°)
# Extracting frames from 0 to 49 (total: 50 frames)
# Extracted 50 frames between key points
# ⬇Downsampled from 50 to 30 frames
# Minimum elbow angle frame 26 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 44_rep_001.mp4
# Success!
#
# [173/182] Processing: incorrect_Copy of push up 46_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 51 frames with pose data
# Minimum elbow angle: 68.5° at frame 34
# Start frame: 0 (angle: 174.8°)
# End frame: 50 (angle: 156.4°)
# Extracting frames from 0 to 50 (total: 51 frames)
# Extracted 51 frames between key points
# ⬇Downsampled from 51 to 30 frames
# Minimum elbow angle frame 34 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 46_flipped_rep_001.mp4
# Success!
#
# [174/182] Processing: incorrect_Copy of push up 46_rep_001.mp4
# Analyzing frames for key points...
# Found 52 frames with pose data
# Minimum elbow angle: 72.8° at frame 32
# Start frame: 0 (angle: 174.6°)
# End frame: 51 (angle: 156.5°)
# Extracting frames from 0 to 51 (total: 52 frames)
# Extracted 52 frames between key points
# ⬇Downsampled from 52 to 30 frames
# Minimum elbow angle frame 32 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 46_rep_001.mp4
# Success!
#
# [175/182] Processing: incorrect_Copy of push up 55_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 68 frames with pose data
# Minimum elbow angle: 61.7° at frame 33
# Start frame: 0 (angle: 171.3°)
# End frame: 67 (angle: 155.3°)
# Extracting frames from 0 to 67 (total: 68 frames)
# Extracted 68 frames between key points
# ⬇Downsampled from 68 to 30 frames
# Minimum elbow angle frame 33 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 55_flipped_rep_001.mp4
# Success!
#
# [176/182] Processing: incorrect_Copy of push up 55_rep_001.mp4
# Analyzing frames for key points...
# Found 69 frames with pose data
# Minimum elbow angle: 59.4° at frame 34
# Start frame: 0 (angle: 168.6°)
# End frame: 68 (angle: 159.1°)
# Extracting frames from 0 to 68 (total: 69 frames)
# Extracted 69 frames between key points
# ⬇Downsampled from 69 to 30 frames
# Minimum elbow angle frame 34 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 55_rep_001.mp4
# Success!
#
# [177/182] Processing: incorrect_Copy of push up 56_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 68 frames with pose data
# Minimum elbow angle: 61.0° at frame 35
# Start frame: 1 (angle: 167.1°)
# End frame: 67 (angle: 156.7°)
# Extracting frames from 1 to 67 (total: 67 frames)
# Extracted 67 frames between key points
# ⬇Downsampled from 67 to 30 frames
# Minimum elbow angle frame 35 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 56_flipped_rep_001.mp4
# Success!
#
# [178/182] Processing: incorrect_Copy of push up 56_rep_001.mp4
# Analyzing frames for key points...
# Found 69 frames with pose data
# Minimum elbow angle: 57.8° at frame 31
# Start frame: 0 (angle: 167.5°)
# End frame: 68 (angle: 160.3°)
# Extracting frames from 0 to 68 (total: 69 frames)
# Extracted 69 frames between key points
# ⬇Downsampled from 69 to 30 frames
# Minimum elbow angle frame 31 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 56_rep_001.mp4
# Success!
#
# [179/182] Processing: incorrect_Copy of push up 57_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 34 frames with pose data
# Minimum elbow angle: 96.7° at frame 17
# Start frame: 0 (angle: 168.4°)
# End frame: 33 (angle: 155.1°)
# Extracting frames from 0 to 33 (total: 34 frames)
# Extracted 34 frames between key points
# ⬇Downsampled from 34 to 30 frames
# Minimum elbow angle frame 17 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 57_flipped_rep_001.mp4
# Success!
#
# [180/182] Processing: incorrect_Copy of push up 57_rep_001.mp4
# Analyzing frames for key points...
# Found 33 frames with pose data
# Minimum elbow angle: 98.3° at frame 19
# Start frame: 0 (angle: 167.4°)
# End frame: 32 (angle: 156.5°)
# Extracting frames from 0 to 32 (total: 33 frames)
# Extracted 33 frames between key points
# ⬇Downsampled from 33 to 30 frames
# Minimum elbow angle frame 19 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 57_rep_001.mp4
# Success!
#
# [181/182] Processing: incorrect_Copy of push up 58_flipped_rep_001.mp4
# Analyzing frames for key points...
# Found 38 frames with pose data
# Minimum elbow angle: 107.0° at frame 23
# Start frame: 0 (angle: 173.4°)
# End frame: 37 (angle: 156.7°)
# Extracting frames from 0 to 37 (total: 38 frames)
# Extracted 38 frames between key points
# ⬇Downsampled from 38 to 30 frames
# Minimum elbow angle frame 23 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 58_flipped_rep_001.mp4
# Success!
#
# [182/182] Processing: incorrect_Copy of push up 58_rep_001.mp4
# Analyzing frames for key points...
# Found 37 frames with pose data
# Minimum elbow angle: 104.6° at frame 24
# Start frame: 0 (angle: 173.7°)
# End frame: 36 (angle: 156.1°)
# Extracting frames from 0 to 36 (total: 37 frames)
# Extracted 37 frames between key points
# ⬇Downsampled from 37 to 30 frames
# Minimum elbow angle frame 24 is guaranteed to be included
# Saved 30 frames to: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys\keyframes_30_incorrect_Copy of push up 58_rep_001.mp4
# Success!
#
# ============================================================
# PROCESSING COMPLETE!
# Successful: 182
# Failed: 0
# Output directory: C:\Users\12484\Desktop\Deep Dive AI Summer 2025\RepKeys
# ============================================================

# %%
print(f"Successful videos: {successful}")
print(f"Failed videos: {failed}")
print(f"Success rate: {(successful/(successful+failed)*100):.1f}%" if (successful+failed) > 0 else "No videos processed")
# Out:
# Successful videos: 182
# Failed videos: 0
# Success rate: 100.0%
